# %%
import pandas as pd
import re
import time
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from nltk.corpus import stopwords
from selenium import webdriver
from textacy.preprocess import preprocess_text
import nltk

from bs4 import BeautifulSoup as bs

# %%
start = time.time()

wd = webdriver.Chrome()

b_summary = []
b_detail = []
b_date = []
b_summary_clean = []
b_detail_clean = []

for i in range(1,8):
    print 'scrapping page : ', i
    url = 'https://ieatandeat.com/page/' + str(i) + '/'   

    try:
        wd.get(url)
    except:
        continue
    response = wd.page_source
    soup = bs(response, 'html.parser')
    
    try:
        blogs = soup.find_all('h3', {'class' : 'entry-title'})
    except:
        continue
        
    for summary in blogs:
        try:
            href = summary.find('a').get('href')
            print 'href : ', href
        except:
            continue            
        
        try:
            wd.get(href)
        except:
            continue
        
        r = wd.page_source
        s = bs(r, 'html.parser')

        # find date
        try:
            date = s.find('span', {'class' : 'dtreviewed'}).find('span').text
        except:
            continue
            
        # find detail
        try:
            y = s.find('div', {'class' : "review"}).find_all('p')
        except:
            continue
        doc = []
        for p in y:
            if p.text:
                doc.append(p.text)
        d = ' '.join(doc)

        b_summary.append(summary.text)
        b_detail.append(d)
        b_date.append(date)
        
        # clean summary and detail 
        clean_summary = preprocess_text(summary.text, fix_unicode=True, lowercase=True, transliterate=True, 
                                                no_numbers=True, no_urls=True, no_emails=True, no_phone_numbers=True, 
                                                no_currency_symbols=True, no_punct=True, no_accents=True)
        
        clean_detail = preprocess_text(d, fix_unicode=True, lowercase=True, transliterate=True, 
                                                no_numbers=True, no_urls=True, no_emails=True, no_phone_numbers=True, 
                                                no_currency_symbols=True, no_punct=True, no_accents=True)
        
        b_summary_clean.append(clean_summary)
        b_detail_clean.append(clean_detail)
        
        print 'cleaned detail snippet : ', clean_detail[:75]
        
end = time.time()
exe_time = (end - start)/60
print 'Time taken :',(exe_time),' minutes'

print len(b_date)
# Out:
# scrapping page :  1
# href :  https://ieatandeat.com/cantonese-delights/
# cleaned detail snippet :  more than half an hour in the queue was well paid off with the sumptuous an
# href :  https://ieatandeat.com/fu-lin-tou-fu-yuen/
# cleaned detail snippet :  at fu lin tou fu yuen the fish cake and house speciality wu xiang are the m
# href :  https://ieatandeat.com/hajjah-mariam-cafe/
# cleaned detail snippet :  hajjah mariam cafe nasi ambeng is decent in taste however what is most impo
# href :  https://ieatandeat.com/black-white-tale/
# href :  https://ieatandeat.com/kam-long-curry-fish-head/
# cleaned detail snippet :  the wellbalancing act of the curry from kam long curry fish head enriches a
# href :  https://ieatandeat.com/cantonese-delights/
# cleaned detail snippet :  more than half an hour in the queue was well paid off with the sumptuous an
# href :  https://ieatandeat.com/fu-lin-tou-fu-yuen/
# cleaned detail snippet :  at fu lin tou fu yuen the fish cake and house speciality wu xiang are the m
# href :  https://ieatandeat.com/hajjah-mariam-cafe/
# cleaned detail snippet :  hajjah mariam cafe nasi ambeng is decent in taste however what is most impo
# href :  https://ieatandeat.com/black-white-tale/
# href :  https://ieatandeat.com/kam-long-curry-fish-head/
# cleaned detail snippet :  the wellbalancing act of the curry from kam long curry fish head enriches a
# href :  https://ieatandeat.com/orchard-cafe-buffet/
# cleaned detail snippet :  orchard cafe is one of the cafes serving better quality paranakan food and
# href :  https://ieatandeat.com/kampong-rojak/
# cleaned detail snippet :  both the rojak and tau kwa pau from kampong rojak are decent in taste and f
# href :  https://ieatandeat.com/clementi-fried-carrot-cake/
# cleaned detail snippet :  clementi fried carrot cake may have it loyal fans judging from the snaking
# href :  https://ieatandeat.com/original-cake/
# cleaned detail snippet :  original cake prides itself for whipping up pillows of soft cottony and bou
# href :  https://ieatandeat.com/best-castella-cake/
# cleaned detail snippet :  castella cake or egg sponge cake has finally found its way into singapore n
# href :  https://ieatandeat.com/cantonese-delights/
# cleaned detail snippet :  more than half an hour in the queue was well paid off with the sumptuous an
# href :  https://ieatandeat.com/fu-lin-tou-fu-yuen/
# cleaned detail snippet :  at fu lin tou fu yuen the fish cake and house speciality wu xiang are the m
# href :  https://ieatandeat.com/hajjah-mariam-cafe/
# cleaned detail snippet :  hajjah mariam cafe nasi ambeng is decent in taste however what is most impo
# href :  https://ieatandeat.com/black-white-tale/
# href :  https://ieatandeat.com/kam-long-curry-fish-head/
# cleaned detail snippet :  the wellbalancing act of the curry from kam long curry fish head enriches a
# scrapping page :  2
# href :  https://ieatandeat.com/tiong-bahru-galicier-pastry/
# cleaned detail snippet :  we do enjoy the kueh dardar and ondehondeh from tiong bahru galicier pastry
# href :  https://ieatandeat.com/ah-hwee-bbq-chicken-wings/
# cleaned detail snippet :  ah hwee bbq chicken wings is general good not to the extent of finger licki
# href :  https://ieatandeat.com/gu-cheng/
# href :  https://ieatandeat.com/bai-nian-niang-dou-fu/
# cleaned detail snippet :  bai nian niang dou fu is wellreserved to be one of the best yong tau fu in
# href :  https://ieatandeat.com/mr-and-mrs-mohgans-super-crispy-roti-prata/
# cleaned detail snippet :  unfortunately after tasting most of the famous roti prata stalls and shops
# href :  https://ieatandeat.com/loos-hainanese-curry-rice/
# cleaned detail snippet :  it is not easy to find a good and all rounded hainanese curry rice however
# href :  https://ieatandeat.com/tai-seng-fish-soup/
# cleaned detail snippet :  the perpetual queue in front of the stall already served as good testimonia
# href :  https://ieatandeat.com/jb-ah-meng-restaurant/
# cleaned detail snippet :  most of the dishes at jb ah meng were created with the chefs passion to ple
# href :  https://ieatandeat.com/hup-chong-hakka-yong-dou-foo/
# cleaned detail snippet :  if we are craving for some good yong dou foo hup chong hakka yong dou foo c
# href :  https://ieatandeat.com/kheng-nan-lee-teochew-porridge/
# cleaned detail snippet :  kheng nan lee teochew porridge or havelock teochew porridge do have some go
# href :  https://ieatandeat.com/cantonese-delights/
# cleaned detail snippet :  more than half an hour in the queue was well paid off with the sumptuous an
# href :  https://ieatandeat.com/fu-lin-tou-fu-yuen/
# cleaned detail snippet :  at fu lin tou fu yuen the fish cake and house speciality wu xiang are the m
# href :  https://ieatandeat.com/hajjah-mariam-cafe/
# cleaned detail snippet :  hajjah mariam cafe nasi ambeng is decent in taste however what is most impo
# href :  https://ieatandeat.com/black-white-tale/
# href :  https://ieatandeat.com/kam-long-curry-fish-head/
# cleaned detail snippet :  the wellbalancing act of the curry from kam long curry fish head enriches a
# scrapping page :  3
# href :  https://ieatandeat.com/lotus-kitchen/
# href :  https://ieatandeat.com/chicken-hotpot/
# cleaned detail snippet :  among the two hotpot we have tried chicken hotpot may deem acceptable with
# href :  https://ieatandeat.com/hua-yu-wee/
# cleaned detail snippet :  hua yu wee seafood attraction lies with its reasonable price generous servi
# href :  https://ieatandeat.com/zion-road-blk91-ann-shun-seafood-soup/
# cleaned detail snippet :  the freshness of the fish and the flavourful deepfried fish able to uplift
# href :  https://ieatandeat.com/soi-19-thai-wanton-mee/
# cleaned detail snippet :  soi number thai wanton mee may appeal a little tame but diehard fans of soi
# href :  https://ieatandeat.com/kow-loon-hong-kong-dim-sum/
# cleaned detail snippet :  the freshness of the handmade dim sum and reasonable price are the main att
# href :  https://ieatandeat.com/dingtele/
# cleaned detail snippet :  on the whole there are some duds in the dishes we ordered however some are
# href :  https://ieatandeat.com/food-lovers-buy-foodie-deals-online/
# href :  https://ieatandeat.com/pranakorn/
# cleaned detail snippet :  there may be inevitably some duds however pranakorn is still a good place f
# href :  https://ieatandeat.com/your-italian-butler-review/
# cleaned detail snippet :  if youre looking for a valueformoney authentic italian meal made using fres
# href :  https://ieatandeat.com/cantonese-delights/
# cleaned detail snippet :  more than half an hour in the queue was well paid off with the sumptuous an
# href :  https://ieatandeat.com/fu-lin-tou-fu-yuen/
# cleaned detail snippet :  at fu lin tou fu yuen the fish cake and house speciality wu xiang are the m
# href :  https://ieatandeat.com/hajjah-mariam-cafe/
# cleaned detail snippet :  hajjah mariam cafe nasi ambeng is decent in taste however what is most impo
# href :  https://ieatandeat.com/black-white-tale/
# href :  https://ieatandeat.com/kam-long-curry-fish-head/
# cleaned detail snippet :  the wellbalancing act of the curry from kam long curry fish head enriches a
# scrapping page :  4
# href :  https://ieatandeat.com/don-signature-crab/
# cleaned detail snippet :  we may have missed the dons pies but dons signature crabs does provides som
# href :  https://ieatandeat.com/tracy-juice-culture/
# cleaned detail snippet :  tracy juice culture will give a complete different perspective about vegeta
# href :  https://ieatandeat.com/ivins-nyonya-specialties/
# cleaned detail snippet :  ivins nyonya specialties may need to seriously appraise some of the dishes
# href :  https://ieatandeat.com/honestbee-top-15-restaurants-that-deliver-right-to-your-doorstep/
# href :  https://ieatandeat.com/bread-yard/
# href :  https://ieatandeat.com/sukiya/
# href :  https://ieatandeat.com/tai-cheong-bakery/
# cleaned detail snippet :  tai cheong bakery may be good with their bakery items but the mains on the
# href :  https://ieatandeat.com/85-redhill-teochew-fishball-noodles/
# cleaned detail snippet :  at number redhill teochew fishball noodles you can basically savour a reaso
# href :  https://ieatandeat.com/yong-huat/
# cleaned detail snippet :  yong huat is heavyhanded with the use of lard to intensify and lift up the
# href :  https://ieatandeat.com/thai-boat-noodle/
# cleaned detail snippet :  the ba mee come with lava egg veggies char siew copious of lard and crispy
# href :  https://ieatandeat.com/cantonese-delights/
# cleaned detail snippet :  more than half an hour in the queue was well paid off with the sumptuous an
# href :  https://ieatandeat.com/fu-lin-tou-fu-yuen/
# cleaned detail snippet :  at fu lin tou fu yuen the fish cake and house speciality wu xiang are the m
# href :  https://ieatandeat.com/hajjah-mariam-cafe/
# cleaned detail snippet :  hajjah mariam cafe nasi ambeng is decent in taste however what is most impo
# href :  https://ieatandeat.com/black-white-tale/
# href :  https://ieatandeat.com/kam-long-curry-fish-head/
# cleaned detail snippet :  the wellbalancing act of the curry from kam long curry fish head enriches a
# scrapping page :  5
# href :  https://ieatandeat.com/nom-bistro-bakery/
# cleaned detail snippet :  nombistro bakery may not have their specialty in any of the main course how
# href :  https://ieatandeat.com/shun-shun-prawn-mee/
# cleaned detail snippet :  shun shun prawn mee adheres to the basic of offering a simple and comfortin
# href :  https://ieatandeat.com/ah-kwang-kway-chap/
# cleaned detail snippet :  of course it may be not too fair to seal the fate of ah kwang kway chap wit
# href :  https://ieatandeat.com/east-bistro/
# cleaned detail snippet :  the restaurant was almost a full house way before the peak lunch hour durin
# href :  https://ieatandeat.com/heng-long-teochew-porridge/
# cleaned detail snippet :  heng long teochew porridge may perceived as expensive compared to many othe
# href :  https://ieatandeat.com/soon-lee-lor-mee/
# cleaned detail snippet :  soon lee lor mee is being voted one of the best lor mee in singapore if you
# href :  https://ieatandeat.com/t-bobs-corner/
# cleaned detail snippet :  the food quality at t bobs corner is generally acceptable but would not mak
# href :  https://ieatandeat.com/tian-xia-xiao-chi/
# cleaned detail snippet :  we can sense the heart and soul that went into making those cubes from the
# href :  https://ieatandeat.com/ho-jia-bo-fishball-minced-meat-noodle/
# cleaned detail snippet :  the soup is tantalizing and we presumably the soupy version of noodle could
# href :  https://ieatandeat.com/hong-kong-street-family-restaurant/
# cleaned detail snippet :  hong kong street family restaurant is ideal for family with its wide range
# href :  https://ieatandeat.com/cantonese-delights/
# cleaned detail snippet :  more than half an hour in the queue was well paid off with the sumptuous an
# href :  https://ieatandeat.com/fu-lin-tou-fu-yuen/
# cleaned detail snippet :  at fu lin tou fu yuen the fish cake and house speciality wu xiang are the m
# href :  https://ieatandeat.com/hajjah-mariam-cafe/
# cleaned detail snippet :  hajjah mariam cafe nasi ambeng is decent in taste however what is most impo
# href :  https://ieatandeat.com/black-white-tale/
# href :  https://ieatandeat.com/kam-long-curry-fish-head/
# cleaned detail snippet :  the wellbalancing act of the curry from kam long curry fish head enriches a
# scrapping page :  6
# href :  https://ieatandeat.com/a-a-s-s-seafood-soup/
# cleaned detail snippet :  mr lau knows well the need to emulate his rival in the nearby vicinity and
# href :  https://ieatandeat.com/gao-peng-cuisine/
# cleaned detail snippet :  gao peng cuisine may appear to be an ordinary chinese restaurant in the hea
# href :  https://ieatandeat.com/soi-thai-soi-nice/
# href :  https://ieatandeat.com/taipei-food-review/
# href :  https://ieatandeat.com/shabu-sai/
# cleaned detail snippet :  although the soup base may not be too inspiring to our palates shabu sai is
# href :  https://ieatandeat.com/sembawang-traditional-claypot-rice/
# href :  https://ieatandeat.com/whisk-and-paddle/
# cleaned detail snippet :  whisk and paddle is a good place for some comfort food at the same time enj
# href :  https://ieatandeat.com/kl-delight-seafood-restaurant/
# href :  https://ieatandeat.com/lighthouse-bistro-bar/
# href :  https://ieatandeat.com/taichung-food-review/
# href :  https://ieatandeat.com/cantonese-delights/
# cleaned detail snippet :  more than half an hour in the queue was well paid off with the sumptuous an
# href :  https://ieatandeat.com/fu-lin-tou-fu-yuen/
# cleaned detail snippet :  at fu lin tou fu yuen the fish cake and house speciality wu xiang are the m
# href :  https://ieatandeat.com/hajjah-mariam-cafe/
# cleaned detail snippet :  hajjah mariam cafe nasi ambeng is decent in taste however what is most impo
# href :  https://ieatandeat.com/black-white-tale/
# href :  https://ieatandeat.com/kam-long-curry-fish-head/
# cleaned detail snippet :  the wellbalancing act of the curry from kam long curry fish head enriches a
# scrapping page :  7
# href :  https://ieatandeat.com/xiao-ya-tou-restaurant/
# href :  https://ieatandeat.com/siam-square-mookata-review/
# href :  https://ieatandeat.com/lab-made-ice-cream/
# href :  https://ieatandeat.com/sarawak-sibu-kampua-mee/
# href :  https://ieatandeat.com/swee-choon-dim-sum-restaurant/
# cleaned detail snippet :  one of the key successes of swee choon dim sum restaurant popularity is the
# href :  https://ieatandeat.com/best-fish-head-steamboat/
# href :  https://ieatandeat.com/mongkok-dim-sum/
# cleaned detail snippet :  there are hits and misses at mongkok dim sum however the house specialities
# href :  https://ieatandeat.com/aoys-thai-noodles-bar/
# cleaned detail snippet :  aoys thai noodles bar probably dont give you the cloud nine feel but overal
# href :  https://ieatandeat.com/%ef%bb%bftaiwan-yilan-food-review/
# href :  https://ieatandeat.com/bedok-ah-koon-fish-soup/
# cleaned detail snippet :  bedok ah koon fish soup has impressed us both of their fish soup and meat b
# href :  https://ieatandeat.com/cantonese-delights/
# cleaned detail snippet :  more than half an hour in the queue was well paid off with the sumptuous an
# href :  https://ieatandeat.com/fu-lin-tou-fu-yuen/
# cleaned detail snippet :  at fu lin tou fu yuen the fish cake and house speciality wu xiang are the m
# href :  https://ieatandeat.com/hajjah-mariam-cafe/
# cleaned detail snippet :  hajjah mariam cafe nasi ambeng is decent in taste however what is most impo
# href :  https://ieatandeat.com/black-white-tale/
# href :  https://ieatandeat.com/kam-long-curry-fish-head/
# cleaned detail snippet :  the wellbalancing act of the curry from kam long curry fish head enriches a
# Time taken : 39.1937775493  minutes
# 83

# %%
# remove stop words from cleaned summary and cleaned detail and lemmatize them

stoplist = set(stopwords.words('english') + \
               ['number',"singapore", "food", "im", "street", 
                'porn','watch', 'video', 'centre', '...',
                'eat', 'day', 'time', 'cdataadsbygoogle', 'windowadsbygoogle',
                'wa', 'ha', 'come', 'place', 'dish', 'bring', 'think', 'quite','located',
                'month', 'went', 'probably', 'am', 'pm', 'say', 'said','including','year','item',
                'youre', 'sure', 'dont', 'came','really', 'got', 'thing', 'address', 'photo',
                'credit', 'opening', 'hour'] \
                 + list(ENGLISH_STOP_WORDS))

# %%
start = time.time()

summary_tokens = []
for item in b_summary_clean:  
    try:
        Tokens = nltk.word_tokenize(item)
        t = [tok for tok in Tokens if tok not in stoplist]
    except:
        continue
    summary_tokens.append(t)
    
detail_tokens = []
for item in b_detail_clean:  
    try:
        Tokens = nltk.word_tokenize(item)
        t = [tok for tok in Tokens if tok not in stoplist]
    except:
        continue
    detail_tokens.append(t)   

    
end = time.time()
exe_time = end - start
print 'Time taken :',(exe_time),' seconds'
    
print len(summary_tokens)
print len(detail_tokens)
# Out:
# Time taken : 1.03271603584  seconds
# 83
# 83

# %%
start = time.time()

summary_lem =[]
wnl = WordNetLemmatizer()
for item in summary_tokens:
    t = " ".join([wnl.lemmatize(i) for i in item])
    summary_lem.append(t) 
    
detail_lem =[]
wnl = WordNetLemmatizer()
for item in detail_tokens:
    t = " ".join([wnl.lemmatize(i) for i in item])
    detail_lem.append(t)     
   
end = time.time()
exe_time = end - start
print 'Time taken :',(exe_time),' seconds'

print len(summary_lem)
print len(detail_lem)
# Out:
# Time taken : 8.93056201935  seconds
# 83
# 83

# %%
# create final list to fit in dataframe
flist = []
for i in range(len(b_summary)):
    f = [b_summary[i], b_detail[i], b_date[i], summary_lem[i], detail_lem[i]]
    flist.append(f)

# %%
df = pd.DataFrame(flist, columns = ['Title', 'Details', 'Date', 'Processed Summary', 'Processed Detail'])  
df.tail()
# Out:
#                                                 Title  \
# 78            Bedok Ah Koon Fish Soup review – 勿洛亚坤鱼汤
# 79  Cantonese Delights Review 广东小吃 @ Hong Lim Mark...
# 80    Fu Lin Tou Fu Yuen @ East Coast Road 福林豆腐园 –...
# 81   Hajjah Mariam Café Review @ Westgate Mall Jurong
# 82  Kam Long Curry Fish Head Review : Good Food ar...
#
#                                               Details        Date  \
# 78  bedok ah koon fish soup has impressed us both ...  18/02/2017
# 79  more than half an hour in the queue was well p...  29/10/2017
# 80  at fu lin tou fu yuen, the fish cake and house...  26/10/2017
# 81  hajjah mariam café nasi ambeng is decent in ta...  22/10/2017
# 82  the well-balancing act of the curry from kam l...  14/10/2017
#
#                                     Processed Summary  \
# 78  bedok ah koon fish soup review wu luo ya kun y...
# 79  cantonese delight review yan dong xiao chi hon...
# 80  fu lin tou fu yuen east coast road fu lin dou ...
# 81     hajjah mariam cafe review westgate mall jurong
# 82         kam long curry fish head review good johor
#
#                                      Processed Detail
# 78  bedok ah koon fish soup impressed fish soup me...
# 79  half queue paid sumptuous economical meal orde...
# 80  fu lin tou fu yuen fish cake house speciality ...
# 81  hajjah mariam cafe nasi ambeng decent taste im...
# 82  wellbalancing act curry kam long curry fish he...

# %%
len(df)
# Out:
# 83

# %%
df.drop_duplicates(inplace=True)

# %%
len(df)
# Out:
# 53

# %%
x = df.iloc[3,1]
print x
# Out:
# the well-balancing act of the curry from kam long curry fish head enriches a good gourmet experience, making it a pleasant to the taste buds. kam long curry fish head review : good food around johor baru jb city square – 阿福街金龍阿仔咖喱魚頭 kam long curry fish head 金龍咖喱魚頭: a trip to johor baru city square is not just shopping; there are eating places within the walking distance from the city square that ones can find good food with reasonable price. restoran kam long curry fish head 金龍咖喱魚頭 which is about 5 minutes’ walk from the shopping mall is one of the places worth to check out. kam long curry fish head is probably the most popular eating place in jb for it raved about curry fish head. so famous that the waiting time can be as long as one hour during peak hour, we reached there around 10am on a weekday and waited 25 minutes for a table. kam long curry fish head occupied a typical shop house layout with no air conditioning, so prepare to sweat a little with the piping hot curry. fish head rm 24/35/48 fish tail rm 32/42/54 one person rm 20 kam long curry fish head serves only curry fish head and nothing else, fish head was half with small, medium and large size, there was not much the fish meat for the fish head and you may opt for the tail section for a more meaty fish. the curry fish head was cooked with deep fried bean skin, ladyfingers, tomatoes and cabbage. served in a claypot, the dish was bubbling hot when served, curry was slightly watery than the rich and more viscous version, spiciness is well tolerable by most of the people. the quintessence of a good curry lies in the perfect medley of the spices and condiments with freshness of the fish, kam long curry fish head never failed you with the good standard, you can even drink the curry gravy without the feeling of cloying, that’s the unique part of the curry fish head here.  our verdict the well-balancing act of the curry from kam long curry fish head enriches a good gourmet experience, making it a pleasant to the taste buds. restaurant kam long 阿福街金龍阿仔咖喱魚頭 a: 74, jalan wong ah fook, johor bahru 80000 h: 08:00am – 04:00pm daily

# %%
# pickle dataframe
df.to_pickle('ieatandeat.pickle')

# %%
wd.quit()
