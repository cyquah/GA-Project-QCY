# %%
import tweepy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
from unidecode import unidecode

pd.options.display.max_columns = 50
pd.options.display.max_rows = 50
pd.options.display.width = 120

# %%
consumer_key = 'yCX0HfM3kJFmanBlHRqt0T1Of'
consumer_secret = 'i5i1KS42ueAklCKQBAr5Fh3yAMUzwkR5nmhIqjcRFXprsEpAWj'
access_token = '867963177673269248-3C3LGmQablQZKdaM39NI0zdiPFYEhbZ'
access_secret = 'WPW5JhGYkWNqRYgCKUJKcvetdemDJeN8Lt1GL4NP650ec'

auth = tweepy.AppAuthHandler(consumer_key, consumer_secret)

api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
import time

start = time.time()
                                
import sys
import os

searchQuery = 'food'  # this is what we're searching for
maxTweets = 100000 # Some arbitrary large number
tweetsPerQry = 100  # this is the max the API permits

# If results from a specific ID onwards are reqd, set since_id to that ID.
# else default to no lower limit, go as far back as API allows
sinceId = None

# If results only below a specific ID are, set max_id to that ID.
# else default to no upper limit, start from the most recent tweet matching the search query.
max_id = 917423303941378048

tweets = []
tweetCount = 0
print("Downloading max {0} tweets".format(maxTweets))

while tweetCount < maxTweets:
    try:
        if (max_id <= 0):
            if (not sinceId):
                new_tweets = api.search(q=searchQuery, count=tweetsPerQry)
            else:
                new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                        since_id=sinceId)
        else:
            if (not sinceId):
                new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                        max_id=str(max_id - 1))
            else:
                new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                        max_id=str(max_id - 1),
                                        since_id=sinceId)
        if not new_tweets:
            print("No more tweets found")
            break
            
        for tweet in new_tweets:
            tweets.append(tweet)

        tweetCount += len(new_tweets)
        print("Downloaded {0} tweets".format(tweetCount))
        
        max_id = new_tweets[-1].id
    
    except tweepy.TweepError as e:
        # Just exit if any error
        print("some error : " + str(e))
        break

end = time.time()
exe_time = end - start
print 'Time taken :',(exe_time),' seconds'
# Out:
# Downloading max 100000 tweets
# Downloaded 100 tweets
# Downloaded 200 tweets
# Downloaded 300 tweets
# Downloaded 400 tweets
# Downloaded 499 tweets
# Downloaded 599 tweets
# Downloaded 699 tweets
# Downloaded 799 tweets
# Downloaded 899 tweets
# Downloaded 999 tweets
# Downloaded 1099 tweets
# Downloaded 1199 tweets
# Downloaded 1299 tweets
# Downloaded 1399 tweets
# Downloaded 1499 tweets
# Downloaded 1592 tweets
# Downloaded 1689 tweets
# Downloaded 1789 tweets
# Downloaded 1889 tweets
# Downloaded 1989 tweets
# Downloaded 2089 tweets
# Downloaded 2189 tweets
# Downloaded 2289 tweets
# Downloaded 2389 tweets
# Downloaded 2484 tweets
# Downloaded 2584 tweets
# Downloaded 2684 tweets
# Downloaded 2784 tweets
# Downloaded 2884 tweets
# Downloaded 2984 tweets
# Downloaded 3081 tweets
# Downloaded 3180 tweets
# Downloaded 3280 tweets
# Downloaded 3380 tweets
# Downloaded 3480 tweets
# Downloaded 3579 tweets
# Downloaded 3679 tweets
# Downloaded 3779 tweets
# Downloaded 3879 tweets
# Downloaded 90566 tweets
# Downloaded 90666 tweets
# Downloaded 90766 tweets
# Downloaded 90866 tweets
# Downloaded 90966 tweets
# Downloaded 91066 tweets
# Downloaded 91166 tweets
# Downloaded 91266 tweets
# Downloaded 91365 tweets
# Downloaded 91465 tweets
# Downloaded 91565 tweets
# Downloaded 91665 tweets
# Downloaded 91765 tweets
# Downloaded 91865 tweets
# Downloaded 91965 tweets
# Downloaded 92065 tweets
# Downloaded 92165 tweets
# Downloaded 92265 tweets
# Downloaded 92365 tweets
# Downloaded 92465 tweets
# Downloaded 92565 tweets
# Downloaded 92665 tweets
# Downloaded 92754 tweets
# Downloaded 92854 tweets
# Downloaded 92954 tweets
# Downloaded 93054 tweets
# Downloaded 93154 tweets
# Downloaded 93254 tweets
# Downloaded 93354 tweets
# Downloaded 93454 tweets
# Downloaded 93554 tweets
# Downloaded 93654 tweets
# Downloaded 93754 tweets
# Downloaded 93854 tweets
# Downloaded 93954 tweets
# Downloaded 94054 tweets
# Downloaded 94154 tweets
# Downloaded 94254 tweets
# Downloaded 94354 tweets
# Downloaded 94454 tweets
# Downloaded 94554 tweets
# Downloaded 94654 tweets
# Downloaded 94754 tweets
# Downloaded 94854 tweets
# Downloaded 94954 tweets
# Downloaded 95054 tweets
# Downloaded 95154 tweets
# Downloaded 95254 tweets
# Downloaded 95354 tweets
# Downloaded 95454 tweets
# Downloaded 95554 tweets
# Downloaded 95654 tweets
# Downloaded 95754 tweets
# Downloaded 95854 tweets
# Downloaded 95954 tweets
# Downloaded 96054 tweets
# Downloaded 96154 tweets
# Downloaded 96254 tweets
# Downloaded 96354 tweets
# Downloaded 96454 tweets
# Downloaded 96554 tweets
# Downloaded 96654 tweets
# Downloaded 96754 tweets
# Downloaded 96854 tweets
# Downloaded 96954 tweets
# Downloaded 97054 tweets
# Downloaded 97154 tweets
# Downloaded 97254 tweets
# Downloaded 97354 tweets
# Downloaded 97454 tweets
# Downloaded 97554 tweets
# Downloaded 97654 tweets
# Downloaded 97754 tweets
# Downloaded 97851 tweets
# Downloaded 97951 tweets
# Downloaded 98051 tweets
# Downloaded 98151 tweets
# Downloaded 98251 tweets
# Downloaded 98351 tweets
# Downloaded 98448 tweets
# Downloaded 98548 tweets
# Downloaded 98646 tweets
# Downloaded 98746 tweets
# Downloaded 98846 tweets
# Downloaded 98946 tweets
# Downloaded 99046 tweets
# Downloaded 99146 tweets
# Downloaded 99246 tweets
# Downloaded 99346 tweets
# Downloaded 99445 tweets
# Downloaded 99545 tweets
# Downloaded 99645 tweets
# Downloaded 99745 tweets
# Downloaded 99845 tweets
# Downloaded 99945 tweets
# Downloaded 100045 tweets
# Time taken : 3111.58462811  seconds

# %%
print len(tweets)
# Out:
# 100045

# %%
tweet_id = []
results = []
for tweet in tweets:
# if tweet.author.location == "Singapore":
    if (not tweet.retweeted) and ('RT @' not in tweet.text):
        results.append(tweet.text.lower())
        tweet_id.append(tweet.id)
    
print len(results)
print tweet_id[-1]
# Out:
# 45809
# 917302745056600064

# %%
start = time.time()

def no_duplicates(results):
    # to remove duplicate tweets that are not retweets by comparing the first 25 characters of the tweet

    no_dupli = []
    # initialise empty list to contain duplicate tweets once only 
    dup_once = []
    # initialise dup_once ist to contain truncated tweets for comparison
    dup_once_trunc = []
    res_trunc = [x[:25] for x in results]

    for i in range(len(results)):
        # remove truncated item to see if there are other duplicates in the list
        del res_trunc[i]
        if results[i][:25] not in res_trunc:
            no_dupli.append(results[i])
        else:
            # check and input duplicates once only
            if results[i][:25] not in dup_once_trunc:
                    dup_once.append(results[i])
                    dup_once_trunc.append(results[i][:25])
        res_trunc = [x[:25] for x in results]

    no_dupli.extend(dup_once)
            
    return no_dupli

no_dup = no_duplicates(results)

print len(no_dup)

end = time.time()
exe_time = end - start
print 'Time taken :',(exe_time),' seconds'
# Out:
# 39004
# Time taken : 520.956214905  seconds

# %%
# parse html elements
import HTMLParser
html_parser = HTMLParser.HTMLParser()

no_html = []
for i in no_dup:
    i = html_parser.unescape(i)
    no_html.append(i)
    
print len(no_html)
# Out:
# 39004

# %%
# remove urls at the end of the tweet
url_re = 'https:\/\/t\.co\/([a-zA-Z\d]+)'
    
no_url = []
for i in no_html:
    u = re.finditer(url_re , i)
    if u:
        for a in u:
            i = i.replace(a.group(), '')
    # remove newlines including those created when url removed at end of string
    i = i.replace('\n', '')
    no_url.append(i)
    
print len(no_url)
# Out:
# 39004

# %%
# remove any screen names encountered
no_scrname = []
scrname_re = '@([a-zA-Z\d]*)'
for i in no_url:
    u = re.finditer(scrname_re , i)
    if u:
        for a in u:
            i = i.replace(a.group(), '')
    no_scrname.append(i)

# %%
# remove all hashtags
no_hashtag = []
hashtag_re = '#([a-z]+)'

for i in no_scrname:
    u = re.finditer(hashtag_re , i)
    if u:
        for a in u:
            i = i.replace(a.group(), '')
    no_hashtag.append(i)

# %%
no_spec = []
spec_char = ['$', '(', ')','{','}','~','@','#','%','^','&','*',':','|','<',';','[',']']

for i in no_hashtag:
    for char in spec_char:
        i = i.replace(char, '')
    no_spec.append(i)

# %%
no_num = []
num_re = '\d'

for i in no_spec:
    u = re.findall(num_re, i)
    if u:
        for a in u:
            i = i.replace(a , '')
    no_num.append(i)

# %%
# get all a-z characters only and remove emojis, punctuations and special characters
char_only = []
not_char_re = '([^a-z\s]+)'

for i in no_num:
    u = re.findall(not_char_re , i)
    if u:
        for a in u:
            i = i.replace(a , '')
    char_only.append(i)

# %%
tweets = pd.DataFrame(char_only, columns = ['Tweets'])
tweets.tail(10)
# Out:
#                                                   Tweets
# 38994                               icymi hot shot food
# 38995  awesome cooking pork with fresh jackfruit  bea...
# 38996                         copenhagen street food
# 38997               des tages gulaschsuppe      blogger
# 38998  even if we keep a baboon for the next  years g...
# 38999  freeze  your food if you want it to last longe...
# 39000  the location for the new  cafe has been reveal...
# 39001               korean food frankie cosmos  youtube
# 39002  the foodbev team are at  in cologne this week ...
# 39003     fresh coffee fresh scone fresh week

# %%
tweets.to_csv('Tweets100k-5.csv', encoding='utf-8')
